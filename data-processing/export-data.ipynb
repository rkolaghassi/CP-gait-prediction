# %%
#import libraries
import pandas as pd
import os
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from scipy import stats
import scipy 
import numpy as np
from tqdm.notebook import tqdm
from torch import nn, optim
import time  
import torch 
import random
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from datetime import date
import pickle
import sys
import utils

# %%
path= r'D:\Study 2 Data'

# Lists the name of all the files available in path
train_files = os.listdir(path) 
print("Current working directory has been changed ...")

# Changes the working directory to get the data from their location 
os.chdir(path)
cwd = os.getcwd()
print(f'Current working directory is: {cwd}')
print(f"There are {len(train_files)} files in the specified path.")
# Out:
# Current working directory has been changed ...
# Current working directory is: D:\Study 2 Data
# There are 1 files in the specified path.

# %%
# # Store data from csv files into arrays 
alldata = np.zeros((1, 63363, 98), dtype=np.float32) 


for f in tqdm(train_files):
    print(f)
    data = pd.read_csv(f)

    
    
#     if 'L' in f:
#         # print(f)
#         fileVal = np.loadtxt(f, delimiter=",")
#         if fileVal.shape[0] < 2000:
#             alldata_left[L_file, 0:fileVal.shape[0], 0:len(labels)-1] = fileVal #final index is len(labels) - 1 because one more feature 'leg' was added to the data, which is not included in fileVal 
#             L_file += 1
#         else:
#             L_lrg_files.append(f)
#         #test
#         # plt.plot(fileVal[:,0], label = 'fileVal')
#         # plt.plot(alldata_left[L_file, :,0], label = 'copiedVal')
#         # plt.legend()
#         # plt.show()

# # Make the final column 'leg' be ones for left leg 
# # 'leg' = 0 (right leg)
# # 'leg' = 1 (left leg)
# alldata_left[:, :, -1] = 1 

# print(f'shape of alldata_left is: {alldata_left.shape}')
# print(f'shape of alldata_right is: {alldata_right.shape}')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# RP1677 V1 BF T1-5 - All biomechanics data.csv

# %% [markdown]
#     •	'Time',
#     •	'Trials number ',
#     •	"[Book1]Acceleration Ankles Eversion-In'!",
#     •	'Right Ankle Inversion-Eversion',
#     •	'Left Ankle Inversion-Eversion',
#     •	"[Book1]Acceleration Ankles Rotation'!",
#     •	'Right Ankle Rotation',
#     •	'Left Ankle Rotation',
#     •	"[Book1]Acceleration Hips Abduction-Add'!",
#     •	'Right Hip Adduction-Abduction',
#     •	'Left Hip Adduction-Abduction',
#     •	"[Book1]Acceleration Hips Flexion-Exten'!",
#     •	'Right Hip Flexion-Extension',
#     •	'Left Hip Flexion-Extension',
#     •	"[Book1]Acceleration Hips Rotation'!",
#     •	'Right Hip Rotation',
#     •	'Left Hip Rotation',
#     •	"[Book1]Acceleration Knees Abduction-Ad'!",
#     •	'Right Knee Abduction-Adduction',
#     •	'Left Knee Abduction-Adduction',
#     •	"[Book1]Acceleration Knees Flexion-Exte'!",
#     •	'Right Knee Flexion-Extension',
#     •	'Left Knee Flexion-Extension',
#     •	"[Book1]Acceleration Knees Rotation'!",
#     •	'Right Knee Rotation',
#     •	'Left Knee Rotation',
#     •	"[Book1]Acceleration Pelvis'!",
#     •	'Pelvis Tilt',
#     •	'Pelvis Obliquity',
#     •	"[Book1]Ankles Dorsiflexion-Plantarflex'!",
#     •	'Right Ankle Dorsiflexion-Plantarflexion',
#     •	'Left Ankle Dorsiflexion-Plantarflexion',
#     •	"[Book1]Ankles Eversion-Inversion'!",
#     •	'Right Ankle Inversion-Eversion2',
#     •	'Left Ankle Inversion-Eversion3',
#     •	"[Book1]Ankles Rotation'!",
#     •	'Right Ankle Rotation4',
#     •	'Left Ankle Rotation5',
#     •	"[Book1]Hips Abduction-Adduction'!",
#     •	'Right Hip Adduction-Abduction6',
#     •	'Left Hip Adduction-Abduction7',
#     •	"[Book1]Hips Flexion-Extension'!",
#     •	'Right Hip Flexion-Extension8',
#     •	'Left Hip Flexion-Extension9',
#     •	"[Book1]Hips Rotation'!",
#     •	'Right Hip Rotation10',
#     •	'Left Hip Rotation11',
#     •	"[Book1]Knees Abduction-Adduction'!",
#     •	'Right Knee Abduction-Adduction12',
#     •	'Left Knee Abduction-Adduction13',
#     •	"[Book1]Knees Flexion-Extension'!",
#     •	'Right Knee Flexion-Extension14',
#     •	'Left Knee Flexion-Extension15',
#     •	"[Book1]Knees Rotation'!",
#     •	'Right Knee Rotation16',
#     •	'Left Knee Rotation17',
#     •	"[Book1]Pelvis Velocity'!",
#     •	'Pelvis Tilt18',
#     •	'Pelvis Obliquity19',
#     •	'[Book1]Pelvis!',
#     •	'Pelvis Tilt20',
#     •	'Pelvis Obliquity21',
#     •	"[Book1]Torso Velocity'!",
#     •	'Torso Flexion-Extension velocity',
#     •	'Torso Lateral Flexion velocity',
#     •	'[Book1]Torso!',
#     •	'Torso Flexion-Extension',
#     •	'Torso Lateral Flexion',
#     •	"[Book1]Velocity Ankles Dorsiflexion-Pl'!",
#     •	'Right Ankle Dorsiflexion-Plantarflexion22',
#     •	'Left Ankle Dorsiflexion-Plantarflexion23',
#     •	"[Book1]Velocity Ankles Eversion-Invers'!",
#     •	'Right Ankle Inversion-Eversion24',
#     •	'Left Ankle Inversion-Eversion25',
#     •	"[Book1]Velocity Ankles Rotation'!",
#     •	'Right Ankle Rotation26',
#     •	'Left Ankle Rotation27',
#     •	"[Book1]Velocity Hips Abduction-Adducti'!",
#     •	'Right Hip Adduction-Abduction28',
#     •	'Left Hip Adduction-Abduction29',
#     •	"[Book1]Velocity Hips Flexion-Extension'!",
#     •	'Right Hip Flexion-Extension30',
#     •	'Left Hip Flexion-Extension31',
#     •	"[Book1]Velocity Hips Rotation'!",
#     •	'Right Hip Rotation32',
#     •	'Left Hip Rotation33',
#     •	"[Book1]Velocity Knees Abduction-Adduct'!",
#     •	'Right Knee Abduction-Adduction34',
#     •	'Left Knee Abduction-Adduction35',
#     •	"[Book1]Velocity Knees Flexion-Extensio'!",
#     •	'Right Knee Flexion-Extension36',
#     •	'Left Knee Flexion-Extension37',
#     •	"[Book1]Velocity Knees Rotation'!",
#     •	'Right Knee Rotation38',
#     •	'Left Knee Rotation39',
#     •	"[Book1]Velocity Pelvis'!",
#     •	'Pelvis Tilt40',
#     •	'Pelvis Obliquity41'

# %%
    data = data.rename(columns={'Time': 'Time',
    'Trials number ': 'Trial Number',
    "[Book1]Acceleration Ankles Eversion-In'!" : 'ACCEL Ankle Inversion-Eversion',
    'Right Ankle Inversion-Eversion': 'ACCEL R Ankle Inversion-Eversion',
    'Left Ankle Inversion-Eversion': 'ACCEL L Ankle Inversion-Eversion',
    "[Book1]Acceleration Ankles Rotation'!": 'ACCEL Ankle Rotation',
    'Right Ankle Rotation': 'ACCEL R Ankle Rotation',
    'Left Ankle Rotation': 'ACCEL L Ankle Rotation',
    "[Book1]Acceleration Hips Abduction-Add'!" : 'ACCEL Hip Adduction-Abduction',
    'Right Hip Adduction-Abduction': 'ACCEL R Hip Adduction-Abduction',
    'Left Hip Adduction-Abduction': 'ACCEL L Hip Adduction-Abduction',
    "[Book1]Acceleration Hips Flexion-Exten'!": 'ACCEL Hip Flexion-Extension',
    'Right Hip Flexion-Extension': 'ACCEL R Hip Flexion-Extension',
    'Left Hip Flexion-Extension': 'ACCEL L Hip Flexion-Extension',
    "[Book1]Acceleration Hips Rotation'!": 'ACCEL Hip Rotation',
    'Right Hip Rotation': 'ACCEL R Hip Rotation',
    'Left Hip Rotation': 'ACCEL L Hip Rotation',
    "[Book1]Acceleration Knees Abduction-Ad'!":'ACCEL Knee Adduction-Abduction',
    'Right Knee Abduction-Adduction': 'ACCEL R Knee Adduction-Abduction',
    'Left Knee Abduction-Adduction': 'ACCEL L Knee Adduction-Abduction',
    "[Book1]Acceleration Knees Flexion-Exte'!": 'ACCEL Knee Flexion-Extension',
    'Right Knee Flexion-Extension' : 'ACCEL R Knee Flexion-Extension',
    'Left Knee Flexion-Extension': 'ACCEL L Knee Flexion-Extension',
    "[Book1]Acceleration Knees Rotation'!": 'ACCEL Knee Rotation',
    'Right Knee Rotation': 'ACCEL R Knee Rotation',
    'Left Knee Rotation': 'ACCEL L Knee Rotation',
    "[Book1]Acceleration Pelvis'!": 'ACCEL Pelvis',
    'Pelvis Tilt': 'ACCEL Pelvis Tilt',
    'Pelvis Obliquity': 'ACCEL Pelvis Obliquity',
    "[Book1]Ankles Dorsiflexion-Plantarflex'!": 'ANG Ankle Flexion-Extension',
    'Right Ankle Dorsiflexion-Plantarflexion': 'ANG R Ankle Flexion-Extension',
    'Left Ankle Dorsiflexion-Plantarflexion': 'ANG L Ankle Flexion-Extension',
    "[Book1]Ankles Eversion-Inversion'!": 'ANG Ankle Inversion-Eversion',
    'Right Ankle Inversion-Eversion2': 'ANG R Ankle Inversion-Eversion',
    'Left Ankle Inversion-Eversion3': 'ANG L Ankle Inversion-Eversion',
    "[Book1]Ankles Rotation'!": 'ANG Ankle Rotation',
    'Right Ankle Rotation4': 'ANG R Ankle Rotation',
    'Left Ankle Rotation5': 'ANG L Ankle Rotation',
    "[Book1]Hips Abduction-Adduction'!": 'ANG Hip Adduction-Abduction',
    'Right Hip Adduction-Abduction6': 'ANG R Hip Adduction-Abduction',
    'Left Hip Adduction-Abduction7': 'ANG L Hip Adduction-Abuction',
    "[Book1]Hips Flexion-Extension'!": 'ANG Hip Flexion-Extension',
    'Right Hip Flexion-Extension8': 'ANG R Hip Flexion-Extension',
    'Left Hip Flexion-Extension9': 'ANG L Hip Flexion-Extension',
    "[Book1]Hips Rotation'!": 'ANG Hip Rotation',
    'Right Hip Rotation10': 'ANG R Hip Rotation',
    'Left Hip Rotation11': 'ANG L Hip Rotation',
    "[Book1]Knees Abduction-Adduction'!": 'ANG Knee Adduction-Abduction',
    'Right Knee Abduction-Adduction12': 'ANG R Knee Adduction-Abduction',
    'Left Knee Abduction-Adduction13': 'ANG L Knee Adduction-Abduction',
    "[Book1]Knees Flexion-Extension'!" : 'ANG Knee Flexion-Extension',
    'Right Knee Flexion-Extension14': 'ANG R Knee Flexion-Extension',
    'Left Knee Flexion-Extension15': 'ANG L Knee Flexion-Extension',
    "[Book1]Knees Rotation'!" : 'ANG Knee Rotation',
    'Right Knee Rotation16': 'ANG R Knee Rotation',
    'Left Knee Rotation17' : 'ANG L Knee Rotation',
    "[Book1]Pelvis Velocity'!" : 'VEL Pelvis',
    'Pelvis Tilt18': 'VEL Pelvis Tilt',
    'Pelvis Obliquity19': 'VEL Pelvis Obliquity',
    '[Book1]Pelvis!': 'Pelvis',
    'Pelvis Tilt20' : 'Pelvis Tilt',
    'Pelvis Obliquity21': 'Pelvis Obliquity',
    "[Book1]Torso Velocity'!": 'VEL Torso',
    'Torso Flexion-Extension velocity' : 'VEL Torso Flexion-Extension',
    'Torso Lateral Flexion velocity' : 'VEL Torso Lateral Flexion',
    '[Book1]Torso!' : 'Torso',
    'Torso Flexion-Extension' : 'Torso Flexion-Extension',
    'Torso Lateral Flexion': 'Torso Lateral Flexion',
    "[Book1]Velocity Ankles Dorsiflexion-Pl'!" : 'VEL Ankle Flexion-Extension',
    'Right Ankle Dorsiflexion-Plantarflexion22': 'VEL R Ankle Flexion-Extension',
    'Left Ankle Dorsiflexion-Plantarflexion23': 'VEL L Ankle Flexion-Extension',
    "[Book1]Velocity Ankles Eversion-Invers'!": 'VEL Ankle Inversion-Eversion',
    'Right Ankle Inversion-Eversion24': 'VEL R Ankle Inversion-Eversion',
    'Left Ankle Inversion-Eversion25': 'VEL L Ankle Inverison-Eversion',
    "[Book1]Velocity Ankles Rotation'!": 'VEL Ankle Rotation',
    'Right Ankle Rotation26': 'VEL R Ankle Rotation',
    'Left Ankle Rotation27': 'VEL L Ankle Rotation',
    "[Book1]Velocity Hips Abduction-Adducti'!": 'VEL Hip Adduction-Abduction',
    'Right Hip Adduction-Abduction28': 'VEL R Hip Adduction-Abduction',
    'Left Hip Adduction-Abduction29': 'VEL L Hip Adduction-Abduction',
    "[Book1]Velocity Hips Flexion-Extension'!": 'VEL Hip Flexion-Extension',
    'Right Hip Flexion-Extension30': 'VEL R Hip Flexion-Extension',
    'Left Hip Flexion-Extension31': 'VEL L Hip Flexion-Extension',
    "[Book1]Velocity Hips Rotation'!": 'VEL Hip Rotation',
    'Right Hip Rotation32': 'VEL R Hip Rotation',
    'Left Hip Rotation33': 'VEL L Hip Rotation',
    "[Book1]Velocity Knees Abduction-Adduct'!": 'VEL Knee Adduction-Abduction',
    'Right Knee Abduction-Adduction34': 'VEL R Knee Adduction-Abduction',
    'Left Knee Abduction-Adduction35':'VEL L Knee Adduction-Abduction',
    "[Book1]Velocity Knees Flexion-Extensio'!": 'VEL Knee Flexion-Extension',
    'Right Knee Flexion-Extension36': 'VEL R Knee Flexion-Extension',
    'Left Knee Flexion-Extension37': 'VEL L Knee Flexion-Extension',
    "[Book1]Velocity Knees Rotation'!" :'VEL Knee Rotation',
    'Right Knee Rotation38': 'VEL R Knee Rotation',
    'Left Knee Rotation39': 'VEL L Knee Rotation',
    "[Book1]Velocity Pelvis'!": 'VEL Pelvis',
    'Pelvis Tilt40': 'VEL Pelvis Tilt',
    'Pelvis Obliquity41': 'VEL Pelvis Obliquity'})

# %%
data
list(data.columns.values)
# Out:
# ['Time',
#  'Trial Number',
#  'ACCEL Ankle Inversion-Eversion',
#  'ACCEL R Ankle Inversion-Eversion',
#  'ACCEL L Ankle Inversion-Eversion',
#  'ACCEL Ankle Rotation',
#  'ACCEL R Ankle Rotation',
#  'ACCEL L Ankle Rotation',
#  'ACCEL Hip Adduction-Abduction',
#  'ACCEL R Hip Adduction-Abduction',
#  'ACCEL L Hip Adduction-Abduction',
#  'ACCEL Hip Flexion-Extension',
#  'ACCEL R Hip Flexion-Extension',
#  'ACCEL L Hip Flexion-Extension',
#  'ACCEL Hip Rotation',
#  'ACCEL R Hip Rotation',
#  'ACCEL L Hip Rotation',
#  'ACCEL Knee Adduction-Abduction',
#  'ACCEL R Knee Adduction-Abduction',
#  'ACCEL L Knee Adduction-Abduction',
#  'ACCEL Knee Flexion-Extension',
#  'ACCEL R Knee Flexion-Extension',
#  'ACCEL L Knee Flexion-Extension',
#  'ACCEL Knee Rotation',
#  'ACCEL R Knee Rotation',
#  'ACCEL L Knee Rotation',
#  'ACCEL Pelvis',
#  'ACCEL Pelvis Tilt',
#  'ACCEL Pelvis Obliquity',
#  'ANG Ankle Flexion-Extension',
#  'ANG R Ankle Flexion-Extension',
# ...
